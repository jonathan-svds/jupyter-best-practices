# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set();

# %%
x = np.random.random_sample(100) * 50.0

# %%
y = np.sin(x)

# %%
plt.scatter(x, y)

# %%
plt.plot(x,y)
